# %% [markdown]
# # Import necessary libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Download the Dataset

# %%
url = "https://raw.githubusercontent.com/salemprakash/EDA/main/Data/house%20price.csv"
df = pd.read_csv(url)
df.to_csv("Price.csv", index=False)
print("Dataset downloaded and saved as Price.csv")
# Out:
# Dataset downloaded and saved as Price.csv

# %% [markdown]
# # Module - 2

# %%
df.head()
# Out:
#             date      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  02/05/14 0:00   313000.0         3       1.50         1340      7912
# 1  02/05/14 0:00  2384000.0         5       2.50         3650      9050
# 2  02/05/14 0:00   342000.0         3       2.00         1930     11947
# 3  02/05/14 0:00   420000.0         3       2.25         2000      8030
# 4  02/05/14 0:00   550000.0         4       2.50         1940     10500
#
#    floors waterfront  view  condition  sqft_above  sqft_basement  yr_built  \
# 0     1.5          0   0.0          3        1340              0      1955
# 1     2.0          0   4.0          5        3370            280      1921
# 2     1.0          0   0.0          4        1930              0      1966
# 3     1.0          0   0.0          4        1000           1000      1963
# 4     1.0          0   0.0          4        1140            800      1976
#
#    yr_renovated                    street       city  statezip country
# ...

# %%
df['city'].value_counts()
# Out:
# city
# Seattle                1573
# Renton                  293
# Bellevue                286
# Redmond                 235
# Issaquah                187
# Kirkland                187
# Kent                    185
# Auburn                  176
# Sammamish               175
# Federal Way             148
# Shoreline               123
# Woodinville             115
# Maple Valley             96
# Mercer Island            86
# Burien                   74
# Snoqualmie               71
# Kenmore                  66
# Des Moines               58
# North Bend               50
# Covington                43
# Duvall                   42
# Lake Forest Park         36
# Bothell                  33
# Newcastle                33
# SeaTac                   29
# Tukwila                  29
# Vashon                   29
# Enumclaw                 28
# Carnation                22
# Normandy Park            18
# Clyde Hill               11
# Medina                   11
# Fall City                11
# ...

# %%
df.describe()
# Out:
#               price     bedrooms    bathrooms   sqft_living      sqft_lot  \
# count  4.600000e+03  4600.000000  4600.000000   4600.000000  4.600000e+03
# mean   5.519630e+05     3.400870     2.160815   2139.346957  1.485252e+04
# std    5.638347e+05     0.908848     0.783781    963.206916  3.588444e+04
# min    0.000000e+00     0.000000     0.000000    370.000000  6.380000e+02
# 25%    3.228750e+05     3.000000     1.750000   1460.000000  5.000750e+03
# 50%    4.609435e+05     3.000000     2.250000   1980.000000  7.683000e+03
# 75%    6.549625e+05     4.000000     2.500000   2620.000000  1.100125e+04
# max    2.659000e+07     9.000000     8.000000  13540.000000  1.074218e+06
#
#             floors         view    condition   sqft_above  sqft_basement  \
# count  4600.000000  4599.000000  4600.000000  4600.000000    4600.000000
# mean      1.512065     0.240705     3.451739  1827.265435     312.081522
# std       0.538288     0.778481     0.677230   862.168977     464.137228
# ...

# %%
stacked = df.stack()
stacked
# Out:
# 0     date                02/05/14 0:00
#       price                    313000.0
#       bedrooms                        3
#       bathrooms                     1.5
#       sqft_living                  1340
#                             ...
# 4599  yr_renovated                    0
#       street          18717 SE 258th St
#       city                    Covington
#       statezip                 WA 98042
#       country                       USA
# Length: 82794, dtype: object

# %%
stacked.unstack()
# Out:
#                date        price bedrooms bathrooms sqft_living sqft_lot  \
# 0     02/05/14 0:00     313000.0        3       1.5        1340     7912
# 1     02/05/14 0:00    2384000.0        5       2.5        3650     9050
# 2     02/05/14 0:00     342000.0        3       2.0        1930    11947
# 3     02/05/14 0:00     420000.0        3      2.25        2000     8030
# 4     02/05/14 0:00     550000.0        4       2.5        1940    10500
# ...             ...          ...      ...       ...         ...      ...
# 4595  09/07/14 0:00  308166.6667        3      1.75        1510     6360
# 4596  09/07/14 0:00  534333.3333        3       2.5        1460     7573
# 4597  09/07/14 0:00  416904.1667        3       2.5        3010     7014
# 4598  10/07/14 0:00     203400.0        4       2.0        2090     6630
# 4599  10/07/14 0:00     220600.0        3       2.5        1490     8102
#
#      floors waterfront view condition sqft_above sqft_basement yr_built  \
# ...

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 4595    False
# 4596    False
# 4597    False
# 4598    False
# 4599    False
# Length: 4600, dtype: bool

# %%
df.drop_duplicates()
# Out:
#                date         price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0     02/05/14 0:00  3.130000e+05         3       1.50         1340      7912
# 1     02/05/14 0:00  2.384000e+06         5       2.50         3650      9050
# 2     02/05/14 0:00  3.420000e+05         3       2.00         1930     11947
# 3     02/05/14 0:00  4.200000e+05         3       2.25         2000      8030
# 4     02/05/14 0:00  5.500000e+05         4       2.50         1940     10500
# ...             ...           ...       ...        ...          ...       ...
# 4595  09/07/14 0:00  3.081667e+05         3       1.75         1510      6360
# 4596  09/07/14 0:00  5.343333e+05         3       2.50         1460      7573
# 4597  09/07/14 0:00  4.169042e+05         3       2.50         3010      7014
# 4598  10/07/14 0:00  2.034000e+05         4       2.00         2090      6630
# 4599  10/07/14 0:00  2.206000e+05         3       2.50         1490      8102
#
# ...

# %%
df.isnull()
# Out:
#        date  price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0     False  False     False      False        False     False   False
# 1     False  False     False      False        False     False   False
# 2     False  False     False      False        False     False   False
# 3     False  False     False      False        False     False   False
# 4     False  False     False      False        False     False   False
# ...     ...    ...       ...        ...          ...       ...     ...
# 4595  False  False     False      False        False     False   False
# 4596  False  False     False      False        False     False   False
# 4597  False  False     False      False        False     False   False
# 4598  False  False     False      False        False     False   False
# 4599  False  False     False      False        False     False   False
#
#       waterfront   view  condition  sqft_above  sqft_basement  yr_built  \
# ...

# %%
df.isnull().sum()
# Out:
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       4
# view             1
# condition        0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# street           0
# city             0
# statezip         0
# country          1
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# 6

# %%
df.count()
# Out:
# date             4600
# price            4600
# bedrooms         4600
# bathrooms        4600
# sqft_living      4600
# sqft_lot         4600
# floors           4600
# waterfront       4596
# view             4599
# condition        4600
# sqft_above       4600
# sqft_basement    4600
# yr_built         4600
# yr_renovated     4600
# street           4600
# city             4600
# statezip         4600
# country          4599
# dtype: int64

# %%
df1 = df.dropna()

# %%
df1.isnull().sum()
# Out:
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# street           0
# city             0
# statezip         0
# country          0
# dtype: int64

# %%
df1 = df.dropna(subset=['country', 'waterfront'])

# %%
mean_view = df1.view
mean_view.mean()
# Out:
# 0.24053112755768394

# %%
bins = [1000, 2000, 3000, 4000, 5000, 6000, 7000, 8000, 9000, 10000, 11000] 
column_to_bin = "sqft_living" 
category = pd.cut(df[column_to_bin], bins)

# %%
pd.value_counts(category)
# Out:
# C:\Users\KSHIT\AppData\Local\Temp\ipykernel_1332\2654243906.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pd.value_counts(category)
# sqft_living
# (1000, 2000]      2083
# (2000, 3000]      1503
# (3000, 4000]       524
# (4000, 5000]       145
# (5000, 6000]        32
# (6000, 7000]        12
# (7000, 8000]         3
# (8000, 9000]         2
# (9000, 10000]        1
# (10000, 11000]       1
# Name: count, dtype: int64

# %%
TotalSqFeet = df["sqft_living"]
TotalSqFeet[np.abs(TotalSqFeet) > 6000]
# Out:
# 122     13540
# 252      6210
# 462      7270
# 839      6490
# 1182     6040
# 1567     6980
# 2286    10040
# 2328     8670
# 2654     9640
# 2731     6050
# 2761     6430
# 2967     6900
# 3004     6630
# 3202     6390
# 3559     6640
# 3729     7050
# 4135     6500
# 4138     7320
# 4283     6070
# 4575     8020
# Name: sqft_living, dtype: int64

# %% [markdown]
# # Module -3

# %%
df.dtypes
# Out:
# date              object
# price            float64
# bedrooms           int64
# bathrooms        float64
# sqft_living        int64
# sqft_lot           int64
# floors           float64
# waterfront        object
# view             float64
# condition          int64
# sqft_above         int64
# sqft_basement      int64
# yr_built           int64
# yr_renovated       int64
# street            object
# city              object
# statezip          object
# country           object
# dtype: object

# %%
df['sqft_living'] = df['sqft_living'].astype(str)
print(df['sqft_living'].str.isnumeric().value_counts())
# Out:
# sqft_living
# True    4600
# Name: count, dtype: int64

# %%
df['sqft_living'].loc[df['sqft_living'].str.isnumeric() == True]
# Out:
# 0       1340
# 1       3650
# 2       1930
# 3       2000
# 4       1940
#         ...
# 4595    1510
# 4596    1460
# 4597    3010
# 4598    2090
# 4599    1490
# Name: sqft_living, Length: 4600, dtype: object

# %%
df["sqft_living"] = pd.to_numeric(df["sqft_living"])
mean = df["sqft_living"].mean()
median =df["sqft_living"].median()
mode = df["sqft_living"].mode()
print(mean , median, mode)
# Out:
# 2139.3469565217392 1980.0 0    1720
# 1    1940
# Name: sqft_living, dtype: int64

# %%
df.sqft_living.value_counts().nlargest(30).plot(kind='bar', figsize=(10,6))
plt.title("Number of rooms by sqft_living")
plt.ylabel('Number of rooms')
plt.xlabel('sqft_living of the room')
# Out:
# Text(0.5, 0, 'sqft_living of the room')

# %%
sns.boxplot(x="sqft_living",data=df)
plt.show()

# %%
plt.scatter(df["sqft_living"], df["sqft_lot"])
plt.title("Scatter Plot for sqft_lot vs sqft_living")
plt.xlabel("sqft_living")
plt.ylabel("sqft_lot")
# Out:
# Text(0, 0.5, 'sqft_lot')

# %%
sns.boxplot(x="bedrooms",y="price",data=df)
plt.show()

# %%
sns.pairplot(df,vars = ['condition', 'sqft_above','sqft_basement'], kind="reg")
plt.show()

# %%
sns.set(style="ticks", color_codes=True)
sns.pairplot(df,height=2,vars = ['condition', 'sqft_above','sqft_basement'], hue="waterfront")
plt.show()

# %%
from scipy import stats

corr = stats.pearsonr(df["sqft_above"], df["sqft_basement"])
print("p-value:\t", corr[1])
print("cor:\t\t", corr[0])
# Out:
# p-value:	 0.008624460814128944
# cor:		 -0.03872298989128165

# %%
correlation = df.corr(method='pearson', numeric_only=True)
correlation
# Out:
#                   price  bedrooms  bathrooms  sqft_living  sqft_lot    floors  \
# price          1.000000  0.200336   0.327110     0.430410  0.050451  0.151461
# bedrooms       0.200336  1.000000   0.545920     0.594884  0.068819  0.177895
# bathrooms      0.327110  0.545920   1.000000     0.761154  0.107837  0.486428
# sqft_living    0.430410  0.594884   0.761154     1.000000  0.210538  0.344850
# sqft_lot       0.050451  0.068819   0.107837     0.210538  1.000000  0.003750
# floors         0.151461  0.177895   0.486428     0.344850  0.003750  1.000000
# view           0.228522  0.111002   0.211996     0.310988  0.073884  0.031423
# condition      0.034915  0.025080  -0.119994    -0.062826  0.000558 -0.275013
# sqft_above     0.367570  0.484705   0.689918     0.876443  0.216455  0.522814
# sqft_basement  0.210427  0.334165   0.298020     0.447206  0.034842 -0.255510
# yr_built       0.021857  0.142461   0.463498     0.287775  0.050706  0.467481
# ...

# %%
sns.heatmap(correlation,xticklabels=correlation.columns,
            yticklabels=correlation.columns)
# Out:
# <Axes: >

# %% [markdown]
# # Module - 3 (Time Series Analysis)

# %%
df['date'] = pd.to_datetime(df['date'])
df.dtypes
# Out:
# C:\Users\KSHIT\AppData\Local\Temp\ipykernel_1332\2506493721.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['date'] = pd.to_datetime(df['date'])
# date             datetime64[ns]
# price                   float64
# bedrooms                  int64
# bathrooms               float64
# sqft_living               int64
# sqft_lot                  int64
# floors                  float64
# waterfront               object
# view                    float64
# condition                 int64
# sqft_above                int64
# sqft_basement             int64
# yr_built                  int64
# yr_renovated              int64
# street                   object
# city                     object
# statezip                 object
# country                  object
# dtype: object

# %%
df = df.set_index('date')
df.tail(3)
# Out:
#                   price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# date
# 2014-09-07  416904.1667         3        2.5         3010      7014     2.0
# 2014-10-07  203400.0000         4        2.0         2090      6630     1.0
# 2014-10-07  220600.0000         3        2.5         1490      8102     2.0
#
#            waterfront  view  condition  sqft_above  sqft_basement  yr_built  \
# date
# 2014-09-07          0   0.0          3        3010              0      2009
# 2014-10-07          0   0.0          3        1070           1020      1974
# 2014-10-07          0   0.0          4        1490              0      1990
#
#             yr_renovated             street       city  statezip country
# date
# 2014-09-07             0   759 Ilwaco Pl NE     Renton  WA 98059     USA
# 2014-10-07             0  5148 S Creston St    Seattle  WA 98178     USA
# 2014-10-07             0  18717 SE 258th St  Covington  WA 98042     USA

# %%
df.index
# Out:
# DatetimeIndex(['2014-02-05', '2014-02-05', '2014-02-05', '2014-02-05',
#                '2014-02-05', '2014-02-05', '2014-02-05', '2014-02-05',
#                '2014-02-05', '2014-02-05',
#                ...
#                '2014-08-07', '2014-08-07', '2014-08-07', '2014-08-07',
#                '2014-09-07', '2014-09-07', '2014-09-07', '2014-09-07',
#                '2014-10-07', '2014-10-07'],
#               dtype='datetime64[ns]', name='date', length=4600, freq=None)

# %%
df['Year'] = df.index.year
df['Month'] = df.index.month
df['Weekday Name'] = df.index.day_name()

# %%
df.sample(5, random_state=0)
# Out:
#                 price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# date
# 2014-05-20   289000.0         3        2.5         2090      4700     2.0
# 2014-06-19   429900.0         4        2.5         2640      8625     2.0
# 2014-04-06   129000.0         1        1.0          650     15364     1.0
# 2014-05-28   600000.0         4        2.0         2510     38141     1.0
# 2014-03-06  1298000.0         4        3.5         2790     10125     1.5
#
#            waterfront  view  condition  sqft_above  sqft_basement  yr_built  \
# date
# 2014-05-20          0   0.0          3        2090              0      2002
# 2014-06-19          0   0.0          3        2640              0      1987
# 2014-04-06          0   0.0          4         650              0      1967
# 2014-05-28          0   0.0          3        2510              0      1960
# 2014-03-06          0   0.0          5        2790              0      1985
#
# ...

# %%
df.loc['2014-05-20']
# Out:
#                  price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# date
# 2014-05-20  730000.000         4       2.50         3230      7331     2.0
# 2014-05-20  551000.000         3       2.50         2830      5802     2.0
# 2014-05-20  271310.000         2       1.00          870      5340     1.5
# 2014-05-20  675000.000         4       3.00         2690     28300     1.0
# 2014-05-20  479000.000         3       2.50         1260       889     3.0
# ...                ...       ...        ...          ...       ...     ...
# 2014-05-20  291000.000         3       1.75         1560      9788     1.0
# 2014-05-20  268971.875         4       2.50         1860      6687     1.0
# 2014-05-20       0.000         4       3.75         3300      4545     1.5
# 2014-05-20  317061.875         3       1.75         1280     10716     1.0
# 2014-05-20   83300.000         3       2.00         1490      7770     1.0
#
# ...

# %%
sns.set(rc={'figure.figsize':(11, 4)}) 
plt.rcParams['figure.figsize'] = (8,5)
plt.rcParams['figure.dpi'] = 150

# %%
df['price'].plot(linewidth=0.25)
# Out:
# <Axes: xlabel='date'>

# %%
cols_to_plot = ['sqft_lot', 'sqft_above', 'sqft_basement']
axes = df[cols_to_plot].plot(marker='*', alpha=0.5,
linestyle='None',figsize=(14, 6), subplots=True) 
for ax in axes:
  ax.set_ylabel('Sqft')

# %%
ax = df.loc['2014', 'price'].plot()
ax.set_ylabel('Price')
# Out:
# Text(0, 0.5, 'Price')

# %%
ax = df.loc['2014-12', 'price'].plot(marker='o', linestyle='-')
ax.set_ylabel('Price')
# Out:
# Text(0, 0.5, 'Price')

# %%
fig, axes = plt.subplots(3, 1, figsize=(8, 7), sharex=True)
for name, ax in zip(['sqft_lot', 'sqft_above', 'sqft_basement'], axes):
  sns.boxplot(data=df, x='Month', y=name, ax=ax)
  ax.set_ylabel('Sqft')
  ax.set_title(name)
  if ax != axes[-1]:
    ax.set_xlabel('')

# %%
sns.boxplot(data=df, x='Weekday Name', y='sqft_lot')
# Out:
# <Axes: xlabel='Weekday Name', ylabel='sqft_lot'>

# %% [markdown]
# # Module - 5

# %%
X = df[['sqft_living', 'price']].dropna().values

# %%
from sklearn.cluster import KMeans

# %%
wcss = []
for i in range(1, 11):
    kmeans = KMeans(n_clusters=i, init='k-means++', random_state=42)
    kmeans.fit(X)
    wcss.append(kmeans.inertia_)

plt.plot(range(1, 11), wcss, marker='o')
plt.title('Elbow Method for Optimal k')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.grid(True)
plt.show()
# Out:
# c:\Users\KSHIT\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\KSHIT\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\KSHIT\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# ...

# %%
kmeans = KMeans(n_clusters = 5, init = 'k-means++', random_state = 42)
y_kmeans = kmeans.fit_predict(X)
# Out:
# c:\Users\KSHIT\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)

# %%
plt.figure(figsize=(10, 6))
plt.scatter(X[y_kmeans == 0, 0], X[y_kmeans == 0, 1], s=100, c='red', label='Cluster 1')
plt.scatter(X[y_kmeans == 1, 0], X[y_kmeans == 1, 1], s=100, c='blue', label='Cluster 2')
plt.scatter(X[y_kmeans == 2, 0], X[y_kmeans == 2, 1], s=100, c='green', label='Cluster 3')
plt.scatter(X[y_kmeans == 3, 0], X[y_kmeans == 3, 1], s=100, c='cyan', label='Cluster 4')
plt.scatter(X[y_kmeans == 4, 0], X[y_kmeans == 4, 1], s=100, c='magenta', label='Cluster 5')

plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1],
            s=300, c='yellow', label='Centroids', edgecolors='black')

plt.title('Clusters of Houses')
plt.xlabel('Living Area (sqft)')
plt.ylabel('Price ($)')
plt.legend()
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(8,5))
plt.title("House Price Distribution", fontsize=16)
plt.xlabel("Price ($)", fontsize=14)
plt.grid(True)
plt.hist(df['price'], color='orange', edgecolor='k', bins=30)
plt.show()

# %%
plt.figure(figsize=(8,5))
plt.title("Number of Bedrooms Distribution", fontsize=16)
plt.xlabel("Number of Bedrooms", fontsize=14)
plt.grid(True)
plt.hist(df['bedrooms'], color='green', edgecolor='k', bins=20)
plt.show()

# %%
X = df[['price', 'sqft_living']].values

# %%
import scipy.cluster.hierarchy as sch
X = df[['price', 'sqft_living']].values

plt.figure(figsize=(15, 6))
plt.title('Dendrogram')
plt.xlabel('Houses')
plt.ylabel('Euclidean Distances')

dendrogram = sch.dendrogram(sch.linkage(X, method='ward'))
plt.show()

# %%
plt.figure(figsize=(15, 6))
plt.title('Dendrogram', fontsize=16)
plt.xlabel('Houses', fontsize=14)
plt.ylabel('Euclidean Distances', fontsize=14)

dendrogram = sch.dendrogram(sch.linkage(X, method='ward'))

cutoff_value = 1.5e7 

plt.axhline(y=cutoff_value, color='red', linestyle='--', linewidth=2)

plt.text(500, cutoff_value + 1e6, 'Suggested Cut-off for Clusters', 
         fontsize=14, color='red', fontweight='bold')

plt.show()

# %% [markdown]
# # Module 7

# %%
sns.set(style="ticks", color_codes=True)
plt.rcParams['figure.figsize'] = (8,5)
plt.rcParams['figure.dpi'] = 150

# %%
print(df.keys())
# Out:
# Index(['price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot', 'floors',
#        'waterfront', 'view', 'condition', 'sqft_above', 'sqft_basement',
#        'yr_built', 'yr_renovated', 'street', 'city', 'statezip', 'country',
#        'Year', 'Month', 'Weekday Name'],
#       dtype='object')

# %%
df.head()
print(df.columns)
print(df.head())
# Out:
# Index(['price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot', 'floors',
#        'waterfront', 'view', 'condition', 'sqft_above', 'sqft_basement',
#        'yr_built', 'yr_renovated', 'street', 'city', 'statezip', 'country',
#        'Year', 'Month', 'Weekday Name'],
#       dtype='object')
#                 price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# date
# 2014-02-05   313000.0         3       1.50         1340      7912     1.5
# 2014-02-05  2384000.0         5       2.50         3650      9050     2.0
# 2014-02-05   342000.0         3       2.00         1930     11947     1.0
# 2014-02-05   420000.0         3       2.25         2000      8030     1.0
# 2014-02-05   550000.0         4       2.50         1940     10500     1.0
#
#            waterfront  view  condition  sqft_above  sqft_basement  yr_built  \
# date
# 2014-02-05          0   0.0          3        1340              0      1955
# ...

# %%
df.isna().sum()
# Out:
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       4
# view             1
# condition        0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# street           0
# city             0
# statezip         0
# country          1
# Year             0
# Month            0
# Weekday Name     0
# dtype: int64

# %%
df_numeric = df.select_dtypes(include=[np.number])

df_numeric = df_numeric.drop(columns=['street', 'city', 'statezip', 'country', 'Year'], errors='ignore')

df_numeric = df_numeric.fillna(df_numeric.mean())

sns.heatmap(df_numeric.corr(), square=True, cmap='RdYlGn')
# Out:
# <Axes: >

# %%
sns.lmplot(x='sqft_living', y='price', data=df)

# %%
X = df[['sqft_living']]
y = df[['price']]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 10)

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
regressor.score(X_test, y_test)
# Out:
# 0.3960240903841604

# %%
y_pred=regressor.predict(X_test)
evaluate = pd.DataFrame({'Actual': y_test.values.flatten(), 'Predicted': y_pred.flatten()})
evaluate.head(10)
# Out:
#       Actual      Predicted
# 0   525000.0  543622.829478
# 1   688000.0  771632.302921
# 2  1712500.0  756431.671359
# 3   720000.0  682961.952138
# 4   735000.0  726030.408233
# 5   350000.0  574024.092604
# 6   510250.0  366282.127911
# 7   308500.0  226943.005251
# 8   495000.0  459766.012023
# 9  1400000.0  523355.320728

# %%
evaluate.head(10).plot(kind = 'bar')
# Out:
# <Axes: >

# %%
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error

print(f"R2 score: {r2_score(y_test, y_pred)}")
print(f"MAE score: {mean_absolute_error(y_test, y_pred)}")
print(f"MSE score: {mean_squared_error(y_test, y_pred)}")
# Out:
# R2 score: 0.3960240903841604
# MAE score: 179262.3646712735
# MSE score: 73882627353.16461
